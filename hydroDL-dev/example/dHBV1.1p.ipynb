# %% [markdown]
# ## **Differentiable parameter learning (dPL) + HBV hydrologic model**
#
# ## By Multi-scale Hydrology, Processes and Intelligence (MHPI) team from The Pennsylvania State University
# ## Dr. Chaopeng Shen's Group in Hydrologic Deep Learning and Modeling
#
# ## **Citations:**
#
# dHBV1.0: Feng, Dapeng, Liu, Jiangtao, Lawson, Kathryn., & Shen, Chaopeng (2022). Differentiable, learnable, regionalized process-based models with multiphysical outputs can approach state-of-the-art hydrologic prediction accuracy. Water Resources Research, 58, e2022WR032404. https://doi.org/10.1029/2022WR032404
#
# dHBV1.1p: Yalan Song, Kamlesh Sawadekar, Jonathan M Frame, et al. Physics-informed, Differentiable Hydrologic  Models for Capturing Unseen Extreme Events  . ESS Open Archive . March 14, 2025. https://doi.org/10.22541/essoar.172304428.82707157/v2
#
# ### **Original Code Release**
# Feng, Dapeng, Shen, Chaopeng, Liu, Jiangtao, Lawson, Kathryn, & Beck, Hylke. (2022). differentiable parameter learning (dPL) + HBV hydrologic model. Zenodo. https://doi.org/10.5281/zenodo.7091334

# %%
### Dear Code User,

### Thank you for using our dPL model. We are glad to see our code being
### used to advance research in our field.

### As you use our code, we kindly request that you review and cite
### the relevant papers above that were used to develop the code.
### By doing so, you will help ensure that the contributions of
### the researchers who developed the underlying algorithms
### are properly recognized and appreciated.

### We appreciate your cooperation in this matter and would be happy to
### assist you in finding the appropriate sources to cite.
### If you have any questions or concerns, please do not hesitate to contact us.

### Thank you for your support!
### If you have any question for this release, please contact Dapeng Feng(duf328@psu.edu), Yalan Song (yxs275@psu.edu), or Chaopeng Shen(cshen@engr.psu.edu)

### The code of the differentiable model can be downloaded at https://doi.org/10.5281/zenodo.7091334 or https://github.com/mhpi/dPLHBVrelease
### Reference papers:
### Feng, Dapeng, Jiangtao Liu, Kathryn Lawson, and Chaopeng Shen."Differentiable, Learnable, Regionalized Process‐Based Models With Multiphysical Outputs can Approach State‐Of‐The‐Art Hydrologic Prediction Accuracy." Water Resources Research 58, no. 10 (2022): e2022WR032404.
### Feng, Dapeng, Hylke Beck, Kathryn Lawson, and Chaopeng Shen. "The suitability of differentiable, learnable hydrologic models for ungauged regions and climate change impact assessment." Hydrology and Earth System Sciences (2023). doi: 10.5194/hess-27-2357-2023
### Yalan Song, Kamlesh Sawadekar, Jonathan M Frame, et al. Physics-informed, Differentiable Hydrologic  Models for Capturing Unseen Extreme Events  . ESS Open Archive . March 14, 2025. https://doi.org/10.22541/essoar.172304428.82707157/v2

# %% [markdown]
# # The following code is to prepare the input and target data from CAMELS dataset for differentiable hydrologic models.

# %%
"""
Run this code to download CAMELS data locally and get training_file/validation_file which are pickle files containing numpy floats
change rootDatabase = r"E:\Downloads\CAMELS" below to your download directory. This code works on Linux or Windows.
Afterwards, you can simply use the pickle files (upload to colab if running on colab) defined inline below, e.g.,
train_file = 'training_file' # contains train_x, train_y, train_c as tensors
validation_file = 'validation_file' # contains val_x, val_y, val_c
These variables have not been normalized, and are numpy ndarray as follows:
train_x (forcing data, e.g. precipitation, temperature ...): [pixels, time, features]
train_c (constant data, e.g. soil properties, land cover ...): [pixels, features]
train_y (target variable, e.g. soil moisture, streamflow ...): [pixels, time, 1]
val_x, val_c, val_y
The variables to download, training and test time periods, etc., are defined in the last block of this file. Customize as you wish



**simple directions to get set up with Python on your local computer and run this script: 
Download/install Miniconda (mini version of Python package manager, Anaconda)
save this script file in a new folder
optional** download file from https://gdex.ucar.edu/dataset/camels/file/basin_timeseries_v1p2_metForcing_obsFlow.zip and save to folder (otherwise will autodownload via the script but may fail)
open anaconda prompt (miniconda)
navigate to the folder with your script: cd prints current directory, dir prints directory contents, cd foldername moves your current directory into the named folder

then input the following commands into the command line interface (anaconda prompt):
conda create -n test_hydrodl_tutorial python=3.9 ##Important: We are specifying Python 3.9 due to a number of code dependencies and packages that are not yet fully up to date with the most recent versions of python
#(confirm creation with y)
conda activate test_hydrodl_tutorial
conda install requests tqdm pytorch pandas 
python download_CAMELS_script.py

If all goes well, you will be told files "training_file" and "validation_file" were created in subfolder hydroDLpack. 
Upload these files manually to Colab and make sure they are under the folder "hydroDLpack" there, then continue with the tutorial on colab.

"""

# %%
from pathlib import Path
import sys
import os
root_path = Path.cwd()
target_path = root_path.parent.parent.parent / 'dPLHBVrelease' / 'hydroDL-dev'

sys.path.append(str(target_path))  # Convert Path object to string before appending

print("Model path:", target_path)
# Out:
# Model path: /data/yxs275/DPL_HBV/Zenodo/dHBV1.1p/dPLHBVrelease/hydroDL-dev

# %%
# Where you want your data to be downloaded
rootDatabase = r"/data/yxs275/DPL_HBV/datatest/"
os.chdir(rootDatabase)

# %%
# If you have your CAMELS data downloaded in the path you provided above, you can skip this step! 
import platform

import requests
import zipfile


def download_file(url, destination):
    """Download a file from a specified URL to a given destination."""
    response = requests.get(url, stream=True)
    with open(destination, 'wb') as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)

def downloadCAMELS():
  if platform.system() == 'Windows':

    def unzip_file(source, destination):
        """Unzip a file from a source to a destination."""
        with zipfile.ZipFile(source, 'r') as zip_ref:
            zip_ref.extractall(destination)

    # Base directory
    base_dir = os.getcwd()

    # Create necessary directories
    os.makedirs(base_dir + 'camels_attributes_v2.0/', exist_ok=True)
    os.makedirs(base_dir + 'camels_attributes_v2.0/camels_attributes_v2.0/', exist_ok=True)

    # Download and unzip the main dataset
    main_dataset_url = 'https://gdex.ucar.edu/dataset/camels/file/basin_timeseries_v1p2_metForcing_obsFlow.zip'
    main_dataset_dest = base_dir + 'basin_timeseries_v1p2_metForcing_obsFlow.zip'
    download_file(main_dataset_url, main_dataset_dest)
    unzip_file(main_dataset_dest, base_dir + 'basin_timeseries_v1p2_metForcing_obsFlow/')

    ### Download potential evapotranspiration data
    download_file('https://zenodo.org/record/7943626/files/pet_harg.zip?download=1',base_dir + 'pet_harg.zip')
    unzip_file(base_dir + 'pet_harg.zip', base_dir)


    # List of other files to download
    files_to_download = {
        'https://gdex.ucar.edu/dataset/camels/file/camels_attributes_v2.0.xlsx': 'camels_attributes_v2.0/camels_attributes_v2.0/camels_attributes_v2.0.xlsx',
        'https://gdex.ucar.edu/dataset/camels/file/camels_clim.txt': 'camels_attributes_v2.0/camels_attributes_v2.0/camels_clim.txt',
        'https://gdex.ucar.edu/dataset/camels/file/camels_geol.txt': 'camels_attributes_v2.0/camels_attributes_v2.0/camels_geol.txt',
        'https://gdex.ucar.edu/dataset/camels/file/camels_hydro.txt': 'camels_attributes_v2.0/camels_attributes_v2.0/camels_hydro.txt',
        'https://gdex.ucar.edu/dataset/camels/file/camels_name.txt': 'camels_attributes_v2.0/camels_attributes_v2.0/camels_name.txt',
        'https://gdex.ucar.edu/dataset/camels/file/camels_soil.txt': 'camels_attributes_v2.0/camels_attributes_v2.0/camels_soil.txt',
        'https://gdex.ucar.edu/dataset/camels/file/camels_topo.txt': 'camels_attributes_v2.0/camels_attributes_v2.0/camels_topo.txt',
        'https://gdex.ucar.edu/dataset/camels/file/camels_vege.txt': 'camels_attributes_v2.0/camels_attributes_v2.0/camels_vege.txt'
    }

    # Download additional files
    for url, dest in files_to_download.items():
        full_dest = os.path.join(base_dir, dest)
        download_file(url, full_dest)

    print("Download and extraction complete.")

# Add additional download and unzip commands as needed

  else:
    base_dir = os.getcwd()
    print("CAMELS data is downloading to ",base_dir)
    # !wget 'https://gdex.ucar.edu/dataset/camels/file/basin_timeseries_v1p2_metForcing_obsFlow.zip' -O {base_dir}'/basin_timeseries_v1p2_metForcing_obsFlow.zip'
    # !unzip -o {base_dir}'/basin_timeseries_v1p2_metForcing_obsFlow.zip' -d {base_dir}'/basin_timeseries_v1p2_metForcing_obsFlow'
    # !mkdir {base_dir}'/camels_attributes_v2.0/'
    # !mkdir {base_dir}'/camels_attributes_v2.0/camels_attributes_v2.0/'
    # !wget 'https://gdex.ucar.edu/dataset/camels/file/camels_attributes_v2.0.xlsx' -O {base_dir}'/camels_attributes_v2.0/camels_attributes_v2.0/camels_attributes_v2.0.xlsx'
    # !wget 'https://gdex.ucar.edu/dataset/camels/file/camels_clim.txt' -O {base_dir}'/camels_attributes_v2.0/camels_attributes_v2.0/camels_clim.txt'
    # !wget 'https://gdex.ucar.edu/dataset/camels/file/camels_geol.txt' -O {base_dir}'/camels_attributes_v2.0/camels_attributes_v2.0/camels_geol.txt'
    # !wget 'https://gdex.ucar.edu/dataset/camels/file/camels_hydro.txt' -O {base_dir}'/camels_attributes_v2.0/camels_attributes_v2.0/camels_hydro.txt'
    # !wget 'https://gdex.ucar.edu/dataset/camels/file/camels_name.txt' -O {base_dir}'/camels_attributes_v2.0/camels_attributes_v2.0/camels_name.txt'
    # !wget 'https://gdex.ucar.edu/dataset/camels/file/camels_soil.txt' -O {base_dir}'/camels_attributes_v2.0/camels_attributes_v2.0/camels_soil.txt'
    # !wget 'https://gdex.ucar.edu/dataset/camels/file/camels_topo.txt' -O {base_dir}'/camels_attributes_v2.0/camels_attributes_v2.0/camels_topo.txt'
    # !wget 'https://gdex.ucar.edu/dataset/camels/file/camels_soil.txt' -O {base_dir}'/camels_attributes_v2.0/camels_attributes_v2.0/camels_soil.txt'
    # !wget 'https://gdex.ucar.edu/dataset/camels/file/camels_vege.txt' -O {base_dir}'/camels_attributes_v2.0/camels_attributes_v2.0/camels_vege.txt'

    ### Download potential evapotranspiration data
    # !wget 'https://zenodo.org/record/7943626/files/pet_harg.zip?download=1' -O {base_dir}'/pet_harg.zip'
    # !unzip -o  {base_dir}'/pet_harg.zip' -d {base_dir}

# caution: long-time needed
# you shouldn't need to run this if you are loading directly from pickle file
downloadCAMELS()
# Out:
# CAMELS data is downloading to  /data/yxs275/DPL_HBV/datatest
# --2025-06-19 17:41:21--  https://gdex.ucar.edu/dataset/camels/file/basin_timeseries_v1p2_metForcing_obsFlow.zip
# Resolving gdex.ucar.edu (gdex.ucar.edu)... 128.117.181.6
# Connecting to gdex.ucar.edu (gdex.ucar.edu)|128.117.181.6|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 3406626583 (3.2G) [application/zip]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/basin_timeseries_v1p2_metForcing_obsFlow.zip’
#
# /data/yxs275/DPL_HB 100%[===================>]   3.17G  61.7MB/s    in 51s
#
# 2025-06-19 17:42:13 (63.7 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/basin_timeseries_v1p2_metForcing_obsFlow.zip’ saved [3406626583/3406626583]
#
# unzip:  cannot find or open /content/basin_timeseries_v1p2_metForcing_obsFlow.zip, /content/basin_timeseries_v1p2_metForcing_obsFlow.zip.zip or /content/basin_timeseries_v1p2_metForcing_obsFlow.zip.ZIP.
# --2025-06-19 17:42:14--  https://gdex.ucar.edu/dataset/camels/file/camels_attributes_v2.0.xlsx
# Resolving gdex.ucar.edu (gdex.ucar.edu)... 128.117.181.6
# Connecting to gdex.ucar.edu (gdex.ucar.edu)|128.117.181.6|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 16278 (16K) [application/vnd.ms-excel]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_attributes_v2.0.xlsx’
#
# /data/yxs275/DPL_HB 100%[===================>]  15.90K  --.-KB/s    in 0s
#
# 2025-06-19 17:42:15 (153 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_attributes_v2.0.xlsx’ saved [16278/16278]
#
# --2025-06-19 17:42:15--  https://gdex.ucar.edu/dataset/camels/file/camels_clim.txt
# Resolving gdex.ucar.edu (gdex.ucar.edu)... 128.117.181.6
# Connecting to gdex.ucar.edu (gdex.ucar.edu)|128.117.181.6|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 100673 (98K) [text/plain]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_clim.txt’
#
# /data/yxs275/DPL_HB 100%[===================>]  98.31K  --.-KB/s    in 0.09s
#
# 2025-06-19 17:42:15 (1.11 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_clim.txt’ saved [100673/100673]
#
# --2025-06-19 17:42:16--  https://gdex.ucar.edu/dataset/camels/file/camels_geol.txt
# Resolving gdex.ucar.edu (gdex.ucar.edu)... 128.117.181.6
# Connecting to gdex.ucar.edu (gdex.ucar.edu)|128.117.181.6|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 71583 (70K) [text/plain]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_geol.txt’
#
# /data/yxs275/DPL_HB 100%[===================>]  69.91K  --.-KB/s    in 0.04s
#
# 2025-06-19 17:42:16 (1.56 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_geol.txt’ saved [71583/71583]
#
# --2025-06-19 17:42:17--  https://gdex.ucar.edu/dataset/camels/file/camels_hydro.txt
# Resolving gdex.ucar.edu (gdex.ucar.edu)... 128.117.181.6
# Connecting to gdex.ucar.edu (gdex.ucar.edu)|128.117.181.6|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 122799 (120K) [text/plain]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_hydro.txt’
#
# /data/yxs275/DPL_HB 100%[===================>] 119.92K  --.-KB/s    in 0.09s
#
# 2025-06-19 17:42:17 (1.35 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_hydro.txt’ saved [122799/122799]
#
# --2025-06-19 17:42:17--  https://gdex.ucar.edu/dataset/camels/file/camels_name.txt
# Resolving gdex.ucar.edu (gdex.ucar.edu)... 128.117.181.6
# Connecting to gdex.ucar.edu (gdex.ucar.edu)|128.117.181.6|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 30417 (30K) [text/plain]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_name.txt’
#
# /data/yxs275/DPL_HB 100%[===================>]  29.70K  --.-KB/s    in 0s
#
# 2025-06-19 17:42:18 (355 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_name.txt’ saved [30417/30417]
#
# --2025-06-19 17:42:18--  https://gdex.ucar.edu/dataset/camels/file/camels_soil.txt
# Resolving gdex.ucar.edu (gdex.ucar.edu)... 128.117.181.6
# Connecting to gdex.ucar.edu (gdex.ucar.edu)|128.117.181.6|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 109125 (107K) [text/plain]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_soil.txt’
#
# /data/yxs275/DPL_HB 100%[===================>] 106.57K  --.-KB/s    in 0.09s
#
# 2025-06-19 17:42:19 (1.21 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_soil.txt’ saved [109125/109125]
#
# --2025-06-19 17:42:19--  https://gdex.ucar.edu/dataset/camels/file/camels_topo.txt
# Resolving gdex.ucar.edu (gdex.ucar.edu)... 128.117.181.6
# Connecting to gdex.ucar.edu (gdex.ucar.edu)|128.117.181.6|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 38677 (38K) [text/plain]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_topo.txt’
#
# /data/yxs275/DPL_HB 100%[===================>]  37.77K  --.-KB/s    in 0s
#
# 2025-06-19 17:42:19 (207 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_topo.txt’ saved [38677/38677]
#
# --2025-06-19 17:42:20--  https://gdex.ucar.edu/dataset/camels/file/camels_soil.txt
# Resolving gdex.ucar.edu (gdex.ucar.edu)... 128.117.181.6
# Connecting to gdex.ucar.edu (gdex.ucar.edu)|128.117.181.6|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 109125 (107K) [text/plain]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_soil.txt’
#
# /data/yxs275/DPL_HB 100%[===================>] 106.57K  --.-KB/s    in 0.09s
#
# 2025-06-19 17:42:20 (1.21 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_soil.txt’ saved [109125/109125]
#
# --2025-06-19 17:42:21--  https://gdex.ucar.edu/dataset/camels/file/camels_vege.txt
# Resolving gdex.ucar.edu (gdex.ucar.edu)... 128.117.181.6
# Connecting to gdex.ucar.edu (gdex.ucar.edu)|128.117.181.6|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 107970 (105K) [text/plain]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_vege.txt’
#
# /data/yxs275/DPL_HB 100%[===================>] 105.44K  --.-KB/s    in 0.09s
#
# 2025-06-19 17:42:21 (1.18 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/camels_attributes_v2.0/camels_attributes_v2.0/camels_vege.txt’ saved [107970/107970]
#
# --2025-06-19 17:42:22--  https://zenodo.org/record/7943626/files/pet_harg.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/7943626/files/pet_harg.zip [following]
# --2025-06-19 17:42:22--  https://zenodo.org/records/7943626/files/pet_harg.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 173328154 (165M) [application/octet-stream]
# Saving to: ‘/data/yxs275/DPL_HBV/datatest/pet_harg.zip’
#
# /data/yxs275/DPL_HB 100%[===================>] 165.30M  33.7MB/s    in 5.6s
#
# 2025-06-19 17:42:28 (29.4 MB/s) - ‘/data/yxs275/DPL_HBV/datatest/pet_harg.zip’ saved [173328154/173328154]
#
# Archive:  /data/yxs275/DPL_HBV/datatest/pet_harg.zip
#    creating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10023000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1013500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10166430.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10172700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10172800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10173450.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10205030.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1022500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10234500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10242000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10244950.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10249300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10258000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10258500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10259000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10259200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10263500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1030500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10310500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1031500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10316500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10329500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10336645.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10336660.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10336740.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10343500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10348850.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/10396000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1047000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1052500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1054200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1055000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1057000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1073000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1078000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11098000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11124500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11141280.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11143000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11148900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11151300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11162500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11176400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11180500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11180960.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1118300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1121000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11224500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1123000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11230500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11237500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11253310.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11264500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11266500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11274500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11274630.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11284400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11299600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1134500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1137500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11381500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11383500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1139000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1139800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1142500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1144000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11451100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11468500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11473900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11475560.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11476600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11478500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11480390.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11481200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11482500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11522500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11523200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11528700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/11532500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1162500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1169000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1170100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1181000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1187300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1195100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12010000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12013500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12020000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12025000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12025700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12035000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12040500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12041200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12043000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12048000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12054000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12056500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12073500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12082500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12092000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12095000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12114500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12115000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12115500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12117000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12141300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12143600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12144000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12145500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12147500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12147600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12167000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12175500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12178100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12186000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12189500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12358500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12374250.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12375900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12377150.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12381400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12383500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12388400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12390700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12411000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12414500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12447390.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12451000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/12488500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13011500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13011900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13018300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13023000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13083000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13161500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13235000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13240000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13310700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13313000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1333000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13331500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13337000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13338500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13340000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/13340600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1350000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1350080.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1350140.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1365000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14020000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14092750.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14096850.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1411300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1413500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14137000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14138800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14138870.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14138900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14139800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14141500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1414500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1415000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14154500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14158500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14158790.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14166500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14182500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14185000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14185900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14187000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14216500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14222500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1423000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14236200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14301000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14303200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14305500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14306340.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14306500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14308990.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14309500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14316700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14325000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1434025.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1435000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14362250.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1439500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1440000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/14400000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1440400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1451800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1466500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1484100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1485500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1486000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1487000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1491000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1510000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1516500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1518862.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1532000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1539000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1542810.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1543000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1543500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1544500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1545600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1547700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1548500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1549500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1550000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1552000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1552500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1557500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1567500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1568000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1580000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1583500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1586610.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1591400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1594950.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1596500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1605500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1606500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1613050.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1620500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1632000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1632900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1634500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1638480.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1639500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1644000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1658500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1664000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1666500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1667500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1669000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/1669520.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2011400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2011460.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2013000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2014000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2015700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2016000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2017500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2018000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2027000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2027500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2028500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2038850.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2046000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2051000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2051500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2053200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2053800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2055100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2056900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2059500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2064000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2065500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2069700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2070000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2074500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2077200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2081500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2082950.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2092500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2096846.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2102908.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2108000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2111180.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2111500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2112120.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2112360.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2118500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2125000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2128000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2137727.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2140991.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2143000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2143040.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2149000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2152100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2177000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2178400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2193340.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2196000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2198100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2202600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2212600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2215100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2216180.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2221525.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2231000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2231342.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2235200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2245500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2246000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2296500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2297155.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2297310.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2298123.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2298608.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2299950.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2300700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2310947.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2312200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2314500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2315500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2324400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2327100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2342933.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2349900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2350900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2361000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2363000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2369800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2371500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2372250.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2374500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2381600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2384540.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2395120.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2408540.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2415000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2422500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2427250.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2430085.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2430615.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2450250.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2464000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2464146.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2464360.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2465493.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2469800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2472000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2472500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2479155.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2479300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2479560.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2481000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/2481510.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3010655.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3011800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3015500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3021350.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3026500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3028000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3049000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3049800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3050000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3066000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3069500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3070500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3076600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3078000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3140000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3144000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3159540.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3161000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3164000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3165000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3170000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3173000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3180500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3182500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3186500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3187500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3213700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3237280.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3237500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3238500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3241500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3280700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3281100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3281500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3285000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3291780.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3300400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3338780.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3340800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3346000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3357350.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3364500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3366500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3368000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3384450.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3439000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3450000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3455500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3456500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3460000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3463300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3471500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3473000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3479000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3488000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3498500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3500000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3500240.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3504000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3574500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3592718.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/3604000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4015330.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4024430.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4027000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4040500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4043050.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4045500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4056500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4057510.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4057800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4059500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4063700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4074950.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4105700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4115265.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4122200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4122500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4124000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4127918.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4127997.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4161580.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4185000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4196800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4197100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4197170.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4213000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4213075.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4216418.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4221000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4224775.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4233000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4256000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/4296000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5056000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5057000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5057200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5062500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5087500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5120500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5123400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5129115.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5131500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5291000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5362000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5393500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5399500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5408000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5412500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5413500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5414000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5444000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5454000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5458000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5466500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5487980.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5488200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5489000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5495000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5495500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5501000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5503800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5507600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5508805.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5514500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5525500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5556500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5584500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5585000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5591550.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5592050.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5592575.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5593575.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5593900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/5595730.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6037500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6043500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6154410.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6188000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6191500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6221400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6224000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6278300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6280300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6289000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6291500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6311000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/daymet/6332515.csv
# ...
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/5593575.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/5593900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/5595730.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6037500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6043500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6154410.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6188000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6191500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6221400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6224000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6278300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6280300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6289000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6291500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6311000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6332515.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6339100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6339500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6344600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6350000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6352000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6353000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6354000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6360500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6404000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6406000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6408700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6409000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6431500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6440200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6441500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6447000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6447500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6450500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6452000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6453600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6464500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6468170.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6468250.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6470800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6477500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6479215.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6479438.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6601000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6614800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6622700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6623800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6632400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6746095.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6784000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6803510.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6803530.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6814000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6847900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6853800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6876700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6878000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6879650.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6885500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6888500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6889200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6889500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6892000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6903400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6906800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6910800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6911900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6917000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6918460.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6919500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6921070.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6921200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/6934000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7014500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7056000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7057500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7060710.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7066000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7067000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7068000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7071500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7083000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7142300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7145700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7148400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7149000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7151500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7167500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7180500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7184000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7195800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7196900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7197000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7208500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7226500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7261000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7263295.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7290650.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7291000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7292500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7295000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7299670.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7301410.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7301500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7315200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7315700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7335700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7340300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7346045.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7359610.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7362100.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7362587.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7373000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7375000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/7376000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8013000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8014500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8023080.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8025500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8029500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8050800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8066200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8066300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8070000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8070200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8079600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8082700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8086212.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8086290.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8101000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8103900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8104900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8109700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8150800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8155200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8158700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8158810.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8164000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8164300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8164600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8165300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8171300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8175000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8176900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8178880.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8189500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8190000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8190500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8194200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8195000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8196000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8198500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8200000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8202700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8267500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8269000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8271000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8324000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8377900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8378500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/8380500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9034900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9035800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9035900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9047700.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9065500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9066000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9066200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9066300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9081600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9107000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9210500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9223000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9306242.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9312600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9352900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9378170.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9378630.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9386900.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9404450.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9430500.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9430600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9447800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9480000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9484000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9484600.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9492400.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9494000.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9497800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9497980.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9505200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9505350.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9505800.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9508300.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9510200.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9512280.csv
#   inflating: /data/yxs275/DPL_HBV/datatest/pet_harg/pet_harg/nldas/9513780.csv

# %%
# DATA extraction function
from hydroDL import utils
import numpy as np
import pickle
def extractCAMELS(Ttrain,attrLst,varF,camels,forType='daymet',subset_train="All",subset_idx = None,file_path=None):

  train_loader = camels.DataframeCamels(subset=subset_train, tRange=Ttrain, forType=forType)
  x = train_loader.getDataTs(varLst=varF, doNorm=False, rmNan=False)
  y = train_loader.getDataObs(doNorm=False, rmNan=False, basinnorm=False)
  c = train_loader.getDataConst(varLst=attrLst, doNorm=False, rmNan=False)


  # Reading prepared PET data
  # Modify this as the directory where you put PET
  PETDir = camels.dirDB + '/pet_harg/' + forType + '/'
  if subset_train=="All":
     usgsIdLst = camels.gageDict['id']
  else:
     usgsIdLst =  subset_train
  if forType == 'maurer':
      tPETRange = [19800101, 20090101]
  else:
      tPETRange = [19800101, 20150101]
  tPETLst = utils.time.tRange2Array(tPETRange)
  ntime = len(tPETLst)


  PETfull = np.empty([len(usgsIdLst), ntime, 1])
  for k in range(len(usgsIdLst)):
      
      dataTemp = camels.readcsvGage(PETDir, usgsIdLst[k], ['PEVAP'], ntime)
      PETfull[k, :, :] = dataTemp

  TtrainLst = utils.time.tRange2Array(Ttrain)
  C, ind1, ind2 = np.intersect1d(TtrainLst, tPETLst, return_indices=True)
  PETUN = PETfull[:, ind2, :]
  PETUN = PETUN[subset_idx, :, :]
  x = np.concatenate([x, PETUN], axis=2)

  # define dataset
  if file_path is not None:
    with open(file_path, 'wb') as f:
      pickle.dump((x, y, c), f)
  return x, y, c

# %%
import os
import hydroDL
from hydroDL.master import default
from hydroDL.data import camels
import numpy as np
import json
# If you already have data extracted in previous runs, set this to True

Justload = False

forType = 'daymet'
Ttrain = [19991001, 20081001] #training period
valid_date = [19861001, 19991001]  # Testing period
#define inputs
if forType == 'daymet':
  varF = [ 'prcp', 'tmean']
else:
  varF = [ 'prcp','tmax']

train_file = 'training_file'
validation_file = 'validation_file'
# Define attributes list
attrLst = [ 'p_mean','pet_mean', 'p_seasonality', 'frac_snow', 'aridity', 'high_prec_freq', 'high_prec_dur',
            'low_prec_freq', 'low_prec_dur', 'elev_mean', 'slope_mean', 'area_gages2', 'frac_forest', 'lai_max',
            'lai_diff', 'gvf_max', 'gvf_diff', 'dom_land_cover_frac', 'dom_land_cover', 'root_depth_50',
            'soil_depth_pelletier', 'soil_depth_statsgo', 'soil_porosity', 'soil_conductivity',
            'max_water_content', 'sand_frac', 'silt_frac', 'clay_frac', 'geol_1st_class', 'glim_1st_class_frac',
            'geol_2nd_class', 'glim_2nd_class_frac', 'carbonate_rocks_frac', 'geol_porostiy', 'geol_permeability']

## Load all 671 basins from CAMELS
# TrainLS =  camels.gageDict['id'].tolist()
subsetPath = str(target_path) + '/example/dPLHBV/Sub531ID.txt'
with open(subsetPath, 'r') as fp:
     TrainLS = json.load(fp)
TrainLS.sort()
TrainInd = [TrainLS.index(j) for j in TrainLS]

camels.initcamels(rootDB=rootDatabase)
opt_data = default.optDataCamels # wrapping options around.
opt_data = default.update(opt_data, varT=varF, varC=attrLst, tRange=Ttrain, forType='forType', subset = TrainLS)

if not Justload:
  forcing_train, target_train, attr_train = extractCAMELS(Ttrain,attrLst,varF,camels,forType=forType,subset_train=TrainLS,subset_idx = TrainInd,file_path=train_file)
  forcing_val, target_val, attr_val = extractCAMELS(valid_date,attrLst,varF,camels,forType=forType,subset_train=TrainLS,subset_idx = TrainInd,file_path=validation_file)

  print(f"written files to: "+rootDatabase+os.path.sep+train_file+" and "+validation_file)
# Out:
# daymet tmean was used!
# read usgs streamflow 6.449719429016113
# read usgs streamflow 6.247171640396118
# read usgs streamflow 6.793026685714722
# daymet tmean was used!
# read usgs streamflow 6.174327373504639
# read usgs streamflow 6.168944597244263
# read usgs streamflow 6.668954610824585
# written files to: /data/yxs275/DPL_HBV/datatest//training_file and validation_file

# %% [markdown]
# ### You want to know about the $\delta$ HBV model
# #### The basic idea of the model is to use an LSTM to generate parameters—either static or dynamic—for the HBV hydrologic model.
# #### The HBV model takes these physical parameters as inputs to simulate streamflow and other internal variables, such as ET, snow water equivalent, and baseflow.
# #### The model can be summarized as:
# $$
# \begin{align}
# \theta_d, \theta_s &= \mathrm{LSTM}(x_{\text{norm}}, A_{\text{norm}}) \\
# Q &= \mathrm{HBV}(x, \theta_d, \theta_s)
# \end{align}
# $$
#
# #### Where \(x\) represents the forcings used to drive the streamflow simulation, including precipitation, mean temperature, and potential evapotranspiration. \(A\) represents the static attributes listed above.
# #### Both \(x\) and \(A\) are concatenated and used as inputs to the LSTM.  Before input, \(x\) and \(A\) need to be normalized.
# #### The HBV model is a process-based model and uses the original (unnormalized) values of \(x\).
# #### $\theta_d$ represents the dynamic parameters generated by the sequence-to-sequence LSTM, which change daily.
# #### $\theta_s$ represents the static parameters and uses the values from the last time step of the LSTM prediction.

# %% [markdown]
# ### You want to know about HBV parameters:
# In $\delta$ HBV1.0 (Feng et al., 2022), $\beta$ (shape coefficient in the soil module) and $\gamma$ (shape coefficient in the evapotranspiration module) are set as dynamic parameters.
# All HBV parameters are: parBETA, parFC, parK0, parK1, parK2, parLP, parPERC, parUZL, parTT, parCFMAX, parCFR, parCWH, parBETAET
# The parameter indices of **$\beta$** (`parBETA`) and **$\gamma$** (`parBETAET`) are [1, 13]. All other parameters are set to static to avoid overfitting.
#
# **$\beta$** (shape coefficient in the soil module) and **$\gamma$** (shape coefficient in the evapotranspiration module) are set as dynamic parameters.
#
# All HBV parameters are: parBETA, parFC, parK0, parK1, parK2, parLP, parPERC, parUZL, parTT, parCFMAX, parCFR, parCWH, parBETAET
#
# The parameter indices of $\beta$ (parBETA) and $\gamma$ (parBETAET) are [1, 13].
#
# In $\delta$ HBV1.1p (Song et al., 2025), All HBV parameters are: parBETA, parFC, parK0, parK1, parK2, parLP, parPERC, parUZL, parTT, parCFMAX, parCFR, parCWH, parBETAET, parC
#
# An additional parameter, `parC`, is introduced to represent upward flow in the HBV model, aiming to improve baseflow simulation.
#
# More details about the HBV model can be found in the appendix of Song et al. (2025).
#
# For $\delta$HBV1.1p, we consider three options for dynamic parameter combinations:
#
# 1. **$\beta$** (`parBETA`) and **$\gamma$** (`parBETAET`), indices **[1, 13]**
#
# 2. **$\beta$** (`parBETA`), **$K_0$** (`parK0`), and **$\gamma$** (`parBETAET`), indices **[1, 3, 13]**
#    *Recommended in Song et al. (2025); improves peak flow performance compared to option 1.*
#
# 3. **$\beta$** (`parBETA`), **$K_0$** (`parK0`), **$UZL$** (`parUZL`), and **$\gamma$** (`parBETAET`), indices **[1, 3, 8, 13]**
#    *Slight improvement over option 2, but adding more dynamic parameters requires caution to avoid overfitting or instability.*
#
# **$K_0$** and **$UZL$** are parameters that control the generation of near-surface flow (fast flow), and are related to time-dependent connectivity and variable source areas within the watershed.
#
# All other parameters are set to static to avoid overfitting.

# %% [markdown]
# ## Let's start to train the differentiable model
# #### The following code is used to train $\delta$ HBV1.1p

# %% [markdown]
# ### Define Statistics Functions and a Scaler
# #### These functions are to normalize inputs (x and A) for LSTM

# %%
# This part defines a hydrology-specific Scaler class that works similar as sklearn.MinMaxScaler
# getStatDic, calcStat, calcStatgamma are supporting functions
# If you want to use it with your own data, you can create your own scaler that can be used to normalize your data
# Later on, we will use this scaler to transform the train and val data

def getStatDic(log_norm_cols, attrLst=None, attrdata=None, seriesLst=None, seriesdata=None):
  statDict = dict()
  # series data
  if seriesLst is not None:
    for k in range(len(seriesLst)):
      var = seriesLst[k]
      if var in log_norm_cols:
        statDict[var] = calcStatgamma(seriesdata[:, :, k])
      else:
        statDict[var] = calcStat(seriesdata[:, :, k])

  # const attribute
  if attrLst is not None:
    for k in range(len(attrLst)):
      var = attrLst[k]
      statDict[var] = calcStat(attrdata[:, k])
  return statDict

def calcStat(x):
  a = x.flatten()
  b = a[~np.isnan(a)]
  p10 = np.percentile(b, 10).astype(float)
  p90 = np.percentile(b, 90).astype(float)
  mean = np.mean(b).astype(float)
  std = np.std(b).astype(float)
  if std < 0.001:
    std = 1
  return [p10, p90, mean, std]

def calcStatgamma(x):  # for daily streamflow and precipitation
  a = x.flatten()
  b = a[~np.isnan(a)]  # kick out Nan
  b = np.log10(
    np.sqrt(b) + 0.1
  )  # do some tranformation to change gamma characteristics
  p10 = np.percentile(b, 10).astype(float)
  p90 = np.percentile(b, 90).astype(float)
  mean = np.mean(b).astype(float)
  std = np.std(b).astype(float)
  if std < 0.001:
    std = 1
  return [p10, p90, mean, std]

def transNormbyDic( x_in, var_lst, stat_dict, log_norm_cols, to_norm):
  if type(var_lst) is str:
    var_lst = [var_lst]
  x = x_in.copy()
  out = np.full(x.shape, np.nan)
  for k in range(len(var_lst)):
    var = var_lst[k]
    stat = stat_dict[var]
    if to_norm is True:
      if len(x.shape) == 3:
        if var in log_norm_cols:
          x[:, :, k] = np.log10(np.sqrt(x[:, :, k]) + 0.1)
        out[:, :, k] = (x[:, :, k] - stat[2]) / stat[3]
      elif len(x.shape) == 2:
        if var in log_norm_cols:
          x[:, k] = np.log10(np.sqrt(x[:, k]) + 0.1)
        out[:, k] = (x[:, k] - stat[2]) / stat[3]
    else:
      if len(x.shape) == 3:
        out[:, :, k] = x[:, :, k] * stat[3] + stat[2]
        if var in log_norm_cols:
          out[:, :, k] = (np.power(10, out[:, :, k]) - 0.1) ** 2
      elif len(x.shape) == 2:
        out[:, k] = x[:, k] * stat[3] + stat[2]
        if var in log_norm_cols:
          out[:, k] = (np.power(10, out[:, k]) - 0.1) ** 2
  return out



class HydroScaler:
  def __init__(self, attrLst, seriesLst,log_norm_cols):
    self.log_norm_cols = log_norm_cols
    self.attrLst = attrLst
    self.seriesLst = seriesLst
    self.stat_dict = None
    

  def fit(self, attrdata, seriesdata):
    self.stat_dict = getStatDic(
      log_norm_cols=self.log_norm_cols,
      attrLst=self.attrLst,
      attrdata=attrdata,
      seriesLst=self.seriesLst,
      seriesdata=seriesdata,
    )

  def transform(self, data, var_list,):

    norm_data = transNormbyDic(
      data, var_list, self.stat_dict, log_norm_cols = self.log_norm_cols, to_norm=True)

    return norm_data

  def fit_transform(self, attrdata, seriesdata):
    self.fit(attrdata, seriesdata)
    attr_norm = self.transform(attrdata, self.attrLst)
    series_norm = self.transform(seriesdata, self.seriesLst)
    return attr_norm, series_norm


# The function it only used for streamflow unit convert.
def basinNorm(x, basinarea, toNorm):
  nd = len(x.shape)
  if nd == 3 and x.shape[2] == 1:
    x = x[:, :, 0]  # unsqueeze the original 3 dimension matrix
  temparea = np.tile(basinarea, (1, x.shape[1]))
  if toNorm is True:
    flow = (x * 0.0283168 * 3600 * 24) / (temparea * (10 ** 6)) * 10 ** 3  # ft^3/s --> mm/day
  else:

    flow = (
            x
            * ((temparea * (10**6)) * (10 ** (-3)))
            / (0.0283168 * 3600 * 24)
        )  # mm/day -->  ft^3/s
  if nd == 3:
    flow = np.expand_dims(flow, axis=2)
  return flow

# %% [markdown]
# ### Initialize hydroDL Library, Set Hyperparameters

# %%
import torch
import time
import os
from tqdm import trange
import random
from hydroDL import master, utils
from hydroDL.model import crit, train
from hydroDL.model import rnn as rnn
from hydroDL.data import camels
from hydroDL.post import plot, stat
import torch.nn.functional as F
import os
import numpy as np
import torch
from collections import OrderedDict
import random
import pandas as pd
import json
import datetime as dt


traingpuid = 0
torch.cuda.set_device(traingpuid)


# Fix random seed
seedid = 111111
random.seed(seedid)
torch.manual_seed(seedid)
np.random.seed(seedid)
torch.cuda.manual_seed(seedid)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Set hyperparameters
EPOCH = 100 
BATCH_SIZE = 100  # Each batch contrains 100 basins to train the LSTM
RHO = 365   ## The time length of LSTM (RHO + BUFFTIME)
HIDDENSIZE = 256 ## Hidden size of LSTM
saveEPOCH = 10  # save model for every "saveEPOCH" epochs
BUFFTIME = 365  ## The first 365 day is used to warmup (spin-up) the states of HBV model
loadTrain = True

# %% [markdown]
# ### Please select your model option in the following cell

# %%
# Model option: "dHBV1.0" "dHBV1.1p"
Model_option = "dHBV1.1p"
# Dynamic paramter option : for "dHBV1.0", please use [1,13];  for "dHBV1.1p",  you can choose [1,13],[1,3,13] (Yalan recommends this option),[1,3,8, 13]
# If you do not want any dynamic parameters: Set it to an empty list
dyn_option = [1,3,13]

# Number of components: 
# One component means a single set of HBV parameters; 
# 16 components mean 16 sets of HBV parameters, used to run 16 parallel HBV simulations — these are then averaged before the routing step.

# Note: Multiple components do not imply model ensembling using different random seeds. 
# We still use a single neural network to generate all sets of parameters.

# Model performance ranking:
# Static parameters with 1 component (1C) < Static parameters with 16 components (16C)  < Dynamic + static parameters with 16 components (16C)

Nmul = 16

# %%
"""
Dataset-specific code to read and scale the data
IF YOU CAN DIRECTLY PROVIDE DATA for train_x, train_y, train_c, val_x, val_y, val_c and scale the data
you can skip this section
The data structure is as follows:
train_x (forcing data, e.g. precipitation, temperature ...), shape: [pixels, time, features]
train_c (constant data, e.g. soil properties, land cover ...), shape: [pixels, features]
target/train_y (e.g. soil moisture, streamflow ...), shape: [pixels, time, 1]
val_x, val_c, val_y
Data type: numpy.float
The Scaler does
attr_norm, series_norm = scaler.fit_transform(train_c, series_data)
val_c = scaler.transform(val_c, attrLst)
val_x = scaler.transform(val_x, varF)
"""

import pickle


# Load X, Y, C from a file
with open(train_file, 'rb') as f:
    forcing_train, target_train, attr_train = pickle.load(f)  # Adjust this line based on your file format
    print('Training forcing dimension:', forcing_train.shape, '(forcing data, e.g. precipitation, temperature ...): [basins, time, features]')
    print('Training attributes dimension:', attr_train.shape, '(constant data, e.g. soil properties, land cover ...): [basins, features]')
    print('Training target dimension:', target_train.shape, '(target variable, e.g. streamflow ...): [basins, time, 1]')
with open(validation_file, 'rb') as g:
    forcing_val, target_val, attr_val= pickle.load(g)  # Adjust this line based on your file format
    print('Testing forcing dimension:', forcing_val.shape)
    print('Testing attributes dimension:', attr_val.shape)
    print('Testing target dimension:', target_val.shape)



if forType == 'daymet':
  varF = [ 'prcp', 'tmean']
else:
  varF = [ 'prcp','tmax']

# Define attributes list
attrLst = [ 'p_mean','pet_mean', 'p_seasonality', 'frac_snow', 'aridity', 'high_prec_freq', 'high_prec_dur',
            'low_prec_freq', 'low_prec_dur', 'elev_mean', 'slope_mean', 'area_gages2', 'frac_forest', 'lai_max',
            'lai_diff', 'gvf_max', 'gvf_diff', 'dom_land_cover_frac', 'dom_land_cover', 'root_depth_50',
            'soil_depth_pelletier', 'soil_depth_statsgo', 'soil_porosity', 'soil_conductivity',
            'max_water_content', 'sand_frac', 'silt_frac', 'clay_frac', 'geol_1st_class', 'glim_1st_class_frac',
            'geol_2nd_class', 'glim_2nd_class_frac', 'carbonate_rocks_frac', 'geol_porostiy', 'geol_permeability']

##Add PET in the time series list
varF = varF + ['pet']
# get a Scaler (similar to sklearn.MinMaxScaler).
# basinNorm function is only for converting the streamflow unit from ft^3/s to mm/day.  The basin area are required. y_temp = train_y/(basinarea)
# If your streamflow is not in the unit of ft^3/s, this function needs to be adapted
basinarea  = attr_train[:,np.where(np.array(attrLst)=='area_gages2')[0]]

##Convert the unit of streamflow to mm/day
train_y = basinNorm(target_train,  basinarea, toNorm=True)

val_y = basinNorm(target_val,  basinarea, toNorm=True)

# Initialize scaler
# This scaler will be used to scale the training data and later for the test as well.
# Calculate the statistics for scaling the training data (x and A); Same statistics should be used for validation data for consistency. 
if Model_option == "dHBV1.1p":
    log_norm_cols = []
elif Model_option == "dHBV1.0":
    log_norm_cols = ['prcp']
else:
    raise ValueError("No such model option. Please reselect it.")

scaler = HydroScaler(attrLst=attrLst, seriesLst=varF, log_norm_cols=log_norm_cols)


# Fit and transform training data

attr_norm, series_norm = scaler.fit_transform(attr_train, forcing_train.copy())
attr_norm[np.isnan(attr_norm)] = 0.0   ## Nomalized attributes for LSTM

train_x = forcing_train  # forcing data      ## Input forcing for the HBV model
train_x[np.isnan(train_x)] = 0.0

train_z = series_norm  # normalized forcing data      ## Nomalized forcing for LSTM
train_z[np.isnan(train_z)] = 0.0

train_c = attr_norm


forcTuple_train = (train_x, train_z)

# Fit and transform validation data

val_c = scaler.transform(attr_val, attrLst)
val_z = scaler.transform(forcing_val.copy(), varF)
val_x = forcing_val
# no need to scale val_y before we transform the prediction back to compare with val_y

# fill some gaps in x. A fill for the normalized data is equal to filling with mean values
# We don't fill y because it will be handled by the loss function
val_c[np.isnan(val_c)] = 0.0
val_z[np.isnan(val_z)] = 0.0
val_x[np.isnan(val_x)] = 0.0



#IF YOU CAN DIRECTLY PROVIDE DATA for train_x, train_y, train_c, val_x, val_y, val_c, and a Scaler and scale the data
# you can skip this section
#later code used scaler.stat_dict that matches with this scaler for testing. That could be changed for your data
# Out:
# Training forcing dimension: (531, 3288, 3) (forcing data, e.g. precipitation, temperature ...): [basins, time, features]
# Training attributes dimension: (531, 35) (constant data, e.g. soil properties, land cover ...): [basins, features]
# Training target dimension: (531, 3288, 1) (target variable, e.g. streamflow ...): [basins, time, 1]
# Testing forcing dimension: (531, 4748, 3)
# Testing attributes dimension: (531, 35)
# Testing target dimension: (531, 4748, 1)

# %%
## Train the model
# define loss function
# dHBV1.1p uses a normalized sequare-error-based loss function
if Model_option == "dHBV1.1p":
    optLoss = default.update(default.optLossComb, name='hydroDL.model.crit.NSELossBatch')
    lossFun = crit.NSELossBatch(np.nanstd(train_y, axis=1))
# dHBV1.0 uses a balances RMSE loss
elif Model_option == "dHBV1.0":
    alpha = 0.25 # a weight for RMSE loss to balance low and peak flow
    optLoss = default.update(default.optLossComb, name='hydroDL.model.crit.RmseLossComb', weight=alpha)
    lossFun = crit.RmseLossComb(alpha=alpha)
else:
    raise ValueError("No such model option. Please reselect it.")

# %%
TDOpt = True
routing = True # Whether to use the routing module for simulated runoff
comprout = False # True is doing routing for each component
compwts = False # True is using weighted average for components; False is the simple mean
pcorr = None # or a list to give the range of precip correction
dydrop = 0.0 # dropout possibility for those dynamic parameters: 0.0 always dynamic; 1.0 always static
staind = -1 # which time step to use from the learned para time series for those static parameters
ETMod = True
tdRep = dyn_option
tdRepS = [str(ix) for ix in dyn_option]
tdRepS_str = "_".join(tdRepS)
if Model_option == "dHBV1.1p":
    Nfea = 14
# dHBV1.0 uses a balances RMSE loss
elif Model_option == "dHBV1.0":
    Nfea = 13
else:
    raise ValueError("No such model option. Please reselect it.")



rootOut = rootDatabase + f"/dHBV1.1demo/"
if os.path.exists(rootOut) is False:
    os.mkdir(rootOut)
rootOut = rootOut + f"/{Model_option}_{tdRepS_str}/"
    
if os.path.exists(rootOut) is False:
    os.mkdir(rootOut)
print('You model will saved in ',rootOut)
# Out:
# You model will saved in  /data/yxs275/DPL_HBV/datatest//dHBV1.1demo//dHBV1.1p_1_3_13/

# %%
# define training options
optTrain = default.update(default.optTrainCamels, miniBatch=[BATCH_SIZE, RHO], nEpoch=EPOCH, saveEpoch=saveEPOCH)
# define output folder to save model results
out = os.path.join(rootOut, f"exp_EPOCH{EPOCH}_BS{BATCH_SIZE}_RHO{RHO}_HS{HIDDENSIZE}_trainBuff{BUFFTIME}_randomseed{seedid}") # output folder to save results
if os.path.exists(out) is False:
    os.mkdir(out)
print('You model will saved in ',out)
# Out:
# You model will saved in  /data/yxs275/DPL_HBV/datatest//dHBV1.1demo//dHBV1.1p_1_3_13/exp_EPOCH100_BS100_RHO365_HS256_trainBuff365_randomseed111111

# %%
# define and load model
Ninv = val_x.shape[-1] + val_c.shape[-1]

if Model_option == "dHBV1.1p":
    modelname = 'HBV1_1p'
# dHBV1.0 uses a balances RMSE loss
elif Model_option == "dHBV1.0":
    modelname = 'HBV1_0'
else:
    raise ValueError("No such model option. Please reselect it.")

model = rnn.dHBVModel(ninv=Ninv, nfea=Nfea, nmul=Nmul, hiddeninv=HIDDENSIZE, inittime=BUFFTIME,
                                routOpt=routing, comprout=comprout, compwts=compwts, staind=staind, tdlst=tdRep,
                                dydrop=dydrop, ETMod=ETMod,model_name = modelname)
# dict only for logging
optModel = OrderedDict(name= Model_option, nx=Ninv, nfea=Nfea, nmul=Nmul, hiddenSize=HIDDENSIZE, doReLU=True,
                        Tinv=Ttrain, Trainbuff=BUFFTIME, routOpt=routing, comprout=comprout, compwts=compwts,
                        pcorr=pcorr, staind=staind, tdlst=tdRep, dydrop=dydrop,buffOpt=0, TDOpt=TDOpt, ETMod=ETMod)
# Wrap up all the training configurations to one dictionary in order to save into "out" folder as logging
masterDict = master.wrapMaster(out, opt_data, optModel, optLoss, optTrain)
master.writeMasterFile(masterDict)
# Out:
# write master file /data/yxs275/DPL_HBV/datatest//dHBV1.1demo//dHBV1.1p_1_3_13/exp_EPOCH100_BS100_RHO365_HS256_trainBuff365_randomseed111111/master.json
# '/data/yxs275/DPL_HBV/datatest//dHBV1.1demo//dHBV1.1p_1_3_13/exp_EPOCH100_BS100_RHO365_HS256_trainBuff365_randomseed111111'

# %%
## Save the statistics 
statFile = os.path.join(out, 'statDict.json')
with open(statFile, 'w') as fp:
    json.dump(scaler.stat_dict, fp, indent=4)

# %%
# Train the model

trainedModel = train.trainModel(
    model,
    forcTuple_train,
    train_y,
    train_c,
    lossFun,
    nEpoch=EPOCH,
    miniBatch=[BATCH_SIZE, RHO],
    saveEpoch=saveEPOCH,
    saveFolder=out,
    bufftime=BUFFTIME)

# %% [markdown]
# ### The model training takes more than 18 hours with GPU for 671 basins and 15 years data.
# ### Here we download a pre-rained model for testing to save  your time.
#
# ## **Let us start to test the model now!**

# %%
if Model_option == "dHBV1.1p":
    # Download the dHBV1.1p model from Google Drive
    # !gdown 1tWMIy243bxt-r6y4yLFsC8cDcHPTO4BE  # dHBV1.1p model file
    # Copy the downloaded model to the output directory with a new name
    # !cp {rootDatabase}/dHBV1_1p_1_3_13_model_Ep100.pt {out}/model_Ep100.pt

elif Model_option == "dHBV1.0":
    # Download the dHBV1.0 model
    # !gdown 1qYUMDQyAZjjtwvRShYwLr4GGq5m6DSYC  # dHBV1.0 model file
    # Copy and rename
    # !cp {rootDatabase}/dHBV1_0_1_13_model_Ep100.pt {out}/model_Ep100.pt

else:
    raise ValueError("No such model option. Please reselect it.")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tWMIy243bxt-r6y4yLFsC8cDcHPTO4BE
# To: /data/yxs275/DPL_HBV/datatest/dHBV1_1p_1_3_13_model_Ep100.pt
# 100%|██████████████████████████████████████| 4.48M/4.48M [00:00<00:00, 56.7MB/s]

# %%
from hydroDL.master import loadModel

print("Load model from ", out)
testepoch = 100
pretrained_model = loadModel(out, epoch=testepoch)
model.inittime = 0
model.lstminv =  pretrained_model.lstminv

val_z_all =val_z #np.concatenate((train_z, val_z),axis = 1) to use the whole training time period as warmup  
val_x_all =val_x #np.concatenate((train_x, val_x),axis = 1) to use the whole training time period as warmup  

val_c_all = np.expand_dims(val_c, axis=1)
val_c_all = np.repeat(val_c_all, val_x_all.shape[1], axis=1)

zTest = np.concatenate([val_z_all, val_c_all], 2)  # Add attributes to historical forcings for LSTM-parameterization

testTuple = (val_x_all, zTest)
testbatch =200

filePathLst = [out+"/Qs",out+"/Q0",out+"/Q1",out+"/Q2",out+"/ET"]
train.testModel(
    model, testTuple, c=None, batchSize=testbatch, filePathLst=filePathLst)
# Out:
# Load model from  /data/yxs275/DPL_HBV/datatest//dHBV1.1demo//dHBV1.1p_1_3_13/exp_EPOCH100_BS100_RHO365_HS256_trainBuff365_randomseed111111
# /data/yxs275/DPL_HBV/Zenodo/dHBV1.1p/dPLHBVrelease/hydroDL-dev/hydroDL/model/train.py:159: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(modelFile)
# batch 0
# /data/yxs275/DPL_HBV/Zenodo/dHBV1.1p/dPLHBVrelease/hydroDL-dev/hydroDL/model/rnn.py:321: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at ../aten/src/ATen/native/cudnn/RNN.cpp:1424.)
#   output, hy, cy, reserve, new_weight_buf = torch._cudnn_rnn(
# batch 1
# batch 2

# %%
# This first three year is used to warmup model states.
warmup = pd.date_range(f'{1986}-10-01', f'{1989}-09-30', freq='d')
dataPred = pd.read_csv(  out+"/Qs", dtype=np.float32, header=None).values
dataPred = np.expand_dims(dataPred, axis=-1)


evaDict = [stat.statError(dataPred[:,len(warmup):,0], val_y[:,len(warmup):,0])]
evaDictLst = evaDict
keyLst = ['NSE', 'KGE','FLV','FHV', 'lowRMSE', 'highRMSE']
dataBox = list()
for iS in range(len(keyLst)):
    statStr = keyLst[iS]
    temp = list()
    for k in range(len(evaDictLst)):
        data = evaDictLst[k][statStr]
        #data = data[~np.isnan(data)]
        temp.append(data)
    dataBox.append(temp)


print("dHBV model'NSE', 'KGE','absFLV','absFHV', 'lowRMSE', 'highRMSE'",
      np.nanmedian(dataBox[0][0]),
      np.nanmedian(dataBox[1][0]), np.nanmedian(dataBox[2][0]), np.nanmedian(dataBox[3][0]),
      np.nanmedian(dataBox[4][0]), np.nanmedian(dataBox[5][0]))
# Out:
# /data/yxs275/DPL_HBV/Zenodo/dHBV1.1p/dPLHBVrelease/hydroDL-dev/hydroDL/post/stat.py:60: RuntimeWarning: divide by zero encountered in double_scalars
#   PBiaslow[k] = np.sum(lowpred - lowtarget) / np.sum(lowtarget) * 100
# dHBV model'NSE', 'KGE','absFLV','absFHV', 'lowRMSE', 'highRMSE' 0.7508290344337746 0.7584913167268741 13.688217778028086 -14.292147055739534 0.06578258920559231 3.309913455796522
